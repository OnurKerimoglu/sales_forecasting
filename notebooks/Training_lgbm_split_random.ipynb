# %% [markdown]
# # Prediction Pipeline: LGBM with fully random train-val splitting

# %%
# local imports
from model_tools import PredictorData
from tree_models import LGBM_Predictor
from utils import Utils

# %%
config = Utils.read_config_for_env(config_path='../config/config.yml')
pred_data = PredictorData(
    config,
    refresh_monthly=False,
    refresh_ts_features=False,
    clean_strategy='olrem_for_all',
    split_strategy='random',
    # split_strategy='last_months_val',
    # split_strategy='months',
    num_lag_mon=3,
    val_ratio=0.2)
# Out:
# Loading data.. Done.
# Fixing data schemas.. Done.
# Loading /home/onur/WORK/DS/repos/shop_sales_prediction/data/all_ts.parquet

# %% [markdown]
# ## Basic LightGBM model

# %%
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_squared_error as mse

# %%
lgbm_predictor = LGBM_Predictor(
        pred_data=pred_data)

# %%
lgbm_predictor.pred_data = lgbm_predictor.split_transform(
        lgbm_predictor.pred_data,
        lgbm_predictor.transformer)
# Out:
# Splitting train-val
# Fit-transforming X_train
# Transforming X_val

# %%
# Create a LightGBM dataset for training with features X_train and labels Y_train 
train_data = lgb.Dataset(
    lgbm_predictor.pred_data.X_train,
    label=lgbm_predictor.pred_data.y_train,
    feature_name=lgbm_predictor.pred_data.transformed_feature_names) 
# Create a LightGBM dataset for testing with features X_val and labels Y_val, 
# and specify the reference dataset as train_data for consistent evaluation 
val_data = lgb.Dataset(
    lgbm_predictor.pred_data.X_val,
    label=lgbm_predictor.pred_data.y_val,
    feature_name=lgbm_predictor.pred_data.transformed_feature_names,
    reference=train_data) 
# Define a dictionary of parameters for configuring the LightGBM regression model.

# %%
params = { 
    'objective': 'regression',
    'metric': 'mse',
    'boosting_type': 'gbdt',
    'num_leaves': 30,
    'learning_rate': 0.1,
    'feature_fraction': 0.9,
}
callback_early_stopping = lgb.early_stopping(5)
num_round = 100
model = lgb.train(
    params,
    train_data,
    num_round,
    valid_sets=[val_data],
    callbacks=[callback_early_stopping, lgb.log_evaluation()],
)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.343530 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2613
# [LightGBM] [Info] Number of data points in the train set: 31924800, number of used features: 18
# [LightGBM] [Info] Start training from score 0.072491
# [1]	valid_0's l2: 0.568718
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l2: 0.522739
# [3]	valid_0's l2: 0.485461
# [4]	valid_0's l2: 0.455478
# [5]	valid_0's l2: 0.430156
# [6]	valid_0's l2: 0.409909
# [7]	valid_0's l2: 0.393389
# [8]	valid_0's l2: 0.379721
# [9]	valid_0's l2: 0.368454
# [10]	valid_0's l2: 0.358867
# [11]	valid_0's l2: 0.352833
# [12]	valid_0's l2: 0.346103
# [13]	valid_0's l2: 0.340146
# [14]	valid_0's l2: 0.33524
# [15]	valid_0's l2: 0.331098
# [16]	valid_0's l2: 0.327492
# [17]	valid_0's l2: 0.324639
# [18]	valid_0's l2: 0.32199
# [19]	valid_0's l2: 0.319542
# [20]	valid_0's l2: 0.31754
# [21]	valid_0's l2: 0.315796
# [22]	valid_0's l2: 0.314398
# [23]	valid_0's l2: 0.31319
# [24]	valid_0's l2: 0.31196
# [25]	valid_0's l2: 0.310584
# [26]	valid_0's l2: 0.309496
# [27]	valid_0's l2: 0.308498
# [28]	valid_0's l2: 0.30772
# [29]	valid_0's l2: 0.306474
# [30]	valid_0's l2: 0.305774
# [31]	valid_0's l2: 0.305207
# [32]	valid_0's l2: 0.30463
# [33]	valid_0's l2: 0.303763
# [34]	valid_0's l2: 0.303402
# [35]	valid_0's l2: 0.302943
# [36]	valid_0's l2: 0.302669
# [37]	valid_0's l2: 0.302136
# [38]	valid_0's l2: 0.301565
# [39]	valid_0's l2: 0.301444
# [40]	valid_0's l2: 0.301113
# [41]	valid_0's l2: 0.300912
# [42]	valid_0's l2: 0.300699
# [43]	valid_0's l2: 0.300454
# [44]	valid_0's l2: 0.299646
# [45]	valid_0's l2: 0.299458
# [46]	valid_0's l2: 0.299307
# [47]	valid_0's l2: 0.299
# [48]	valid_0's l2: 0.298733
# [49]	valid_0's l2: 0.298276
# [50]	valid_0's l2: 0.2981
# [51]	valid_0's l2: 0.297792
# [52]	valid_0's l2: 0.297633
# [53]	valid_0's l2: 0.297304
# [54]	valid_0's l2: 0.297145
# [55]	valid_0's l2: 0.296287
# [56]	valid_0's l2: 0.296067
# [57]	valid_0's l2: 0.295935
# [58]	valid_0's l2: 0.295559
# [59]	valid_0's l2: 0.295526
# [60]	valid_0's l2: 0.29549
# [61]	valid_0's l2: 0.294742
# [62]	valid_0's l2: 0.294577
# [63]	valid_0's l2: 0.294371
# [64]	valid_0's l2: 0.294266
# [65]	valid_0's l2: 0.294056
# [66]	valid_0's l2: 0.293794
# [67]	valid_0's l2: 0.293429
# [68]	valid_0's l2: 0.293172
# [69]	valid_0's l2: 0.293102
# [70]	valid_0's l2: 0.292862
# [71]	valid_0's l2: 0.292654
# [72]	valid_0's l2: 0.292614
# [73]	valid_0's l2: 0.292543
# [74]	valid_0's l2: 0.292421
# [75]	valid_0's l2: 0.292354
# [76]	valid_0's l2: 0.292137
# [77]	valid_0's l2: 0.292022
# [78]	valid_0's l2: 0.291932
# [79]	valid_0's l2: 0.291776
# [80]	valid_0's l2: 0.291484
# [81]	valid_0's l2: 0.291329
# [82]	valid_0's l2: 0.291261
# [83]	valid_0's l2: 0.291232
# [84]	valid_0's l2: 0.290968
# [85]	valid_0's l2: 0.290735
# [86]	valid_0's l2: 0.290607
# [87]	valid_0's l2: 0.290433
# [88]	valid_0's l2: 0.290256
# [89]	valid_0's l2: 0.290307
# [90]	valid_0's l2: 0.290201
# [91]	valid_0's l2: 0.290049
# [92]	valid_0's l2: 0.290031
# [93]	valid_0's l2: 0.289912
# [94]	valid_0's l2: 0.289875
# [95]	valid_0's l2: 0.289525
# [96]	valid_0's l2: 0.28956
# [97]	valid_0's l2: 0.289459
# [98]	valid_0's l2: 0.289451
# [99]	valid_0's l2: 0.289364
# [100]	valid_0's l2: 0.289307
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's l2: 0.289307

# %%
lgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
# Make predictions on the training and validation data. 
pred_train = model.predict(lgbm_predictor.pred_data.X_train)
pred_val = model.predict(lgbm_predictor.pred_data.X_val)

# Calculate and print the Root Mean Squared Error (RMSE) for training and validation predictions. 
print("Training RMSE: ", np.sqrt(mse(lgbm_predictor.pred_data.y_train, pred_train)))
print("Validation RMSE: ", np.sqrt(mse(lgbm_predictor.pred_data.y_val, pred_val)))
# Out:
# Training RMSE:  0.5281012916325473
# Validation RMSE:  0.5378728401908854

# %% [markdown]
# ## LightGBM tuned with AutoML

# %%
from flaml import AutoML
import numpy as np
import matplotlib.pyplot as plt

# %%
automl = AutoML()
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": "mse",  # primary metrics for regression can be chosen from: ['mae','mse','r2']
    "estimator_list": ["lgbm"],  # list of ML learners; we tune lightgbm in this example
    "task": "regression",  # task type
    "log_file_name": "store_sales_lgbm.log"  # flaml log file
    # "seed": 42,  # random seed
}
automl.fit(
    X_train=lgbm_predictor.pred_data.X_train,
    y_train=lgbm_predictor.pred_data.y_train,
    **settings)
# Out:
# [flaml.automl.logger: 06-09 18:36:22] {1680} INFO - task = regression
# [flaml.automl.logger: 06-09 18:36:22] {1691} INFO - Evaluation method: holdout
# [flaml.automl.logger: 06-09 18:37:35] {1789} INFO - Minimizing error metric: mse
# [flaml.automl.logger: 06-09 18:37:35] {1901} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 06-09 18:37:35] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:35] {2345} INFO - Estimated sufficient time budget=7032750s. Estimated necessary time budget=7033s.
# [flaml.automl.logger: 06-09 18:37:35] {2392} INFO -  at 72.9s,	estimator lgbm's best error=0.6121,	best estimator lgbm's best error=0.6121
# [flaml.automl.logger: 06-09 18:37:35] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:35] {2392} INFO -  at 73.2s,	estimator lgbm's best error=0.6121,	best estimator lgbm's best error=0.6121
# [flaml.automl.logger: 06-09 18:37:35] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:35] {2392} INFO -  at 73.5s,	estimator lgbm's best error=0.6088,	best estimator lgbm's best error=0.6088
# [flaml.automl.logger: 06-09 18:37:35] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:36] {2392} INFO -  at 73.7s,	estimator lgbm's best error=0.5443,	best estimator lgbm's best error=0.5443
# [flaml.automl.logger: 06-09 18:37:36] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:36] {2392} INFO -  at 74.0s,	estimator lgbm's best error=0.5443,	best estimator lgbm's best error=0.5443
# [flaml.automl.logger: 06-09 18:37:36] {2219} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:36] {2392} INFO -  at 74.3s,	estimator lgbm's best error=0.5385,	best estimator lgbm's best error=0.5385
# [flaml.automl.logger: 06-09 18:37:36] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:37] {2392} INFO -  at 74.9s,	estimator lgbm's best error=0.5356,	best estimator lgbm's best error=0.5356
# [flaml.automl.logger: 06-09 18:37:37] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:37] {2392} INFO -  at 75.2s,	estimator lgbm's best error=0.5356,	best estimator lgbm's best error=0.5356
# [flaml.automl.logger: 06-09 18:37:37] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:37] {2392} INFO -  at 75.5s,	estimator lgbm's best error=0.5294,	best estimator lgbm's best error=0.5294
# [flaml.automl.logger: 06-09 18:37:37] {2219} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:38] {2392} INFO -  at 75.8s,	estimator lgbm's best error=0.5235,	best estimator lgbm's best error=0.5235
# [flaml.automl.logger: 06-09 18:37:38] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:38] {2392} INFO -  at 76.1s,	estimator lgbm's best error=0.5235,	best estimator lgbm's best error=0.5235
# [flaml.automl.logger: 06-09 18:37:38] {2219} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:38] {2392} INFO -  at 76.5s,	estimator lgbm's best error=0.5235,	best estimator lgbm's best error=0.5235
# [flaml.automl.logger: 06-09 18:37:38] {2219} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:39] {2392} INFO -  at 76.9s,	estimator lgbm's best error=0.5235,	best estimator lgbm's best error=0.5235
# [flaml.automl.logger: 06-09 18:37:39] {2219} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:39] {2392} INFO -  at 77.3s,	estimator lgbm's best error=0.4515,	best estimator lgbm's best error=0.4515
# [flaml.automl.logger: 06-09 18:37:39] {2219} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:40] {2392} INFO -  at 77.8s,	estimator lgbm's best error=0.4515,	best estimator lgbm's best error=0.4515
# [flaml.automl.logger: 06-09 18:37:40] {2219} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:40] {2392} INFO -  at 78.2s,	estimator lgbm's best error=0.4480,	best estimator lgbm's best error=0.4480
# [flaml.automl.logger: 06-09 18:37:40] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:41] {2392} INFO -  at 78.8s,	estimator lgbm's best error=0.4480,	best estimator lgbm's best error=0.4480
# [flaml.automl.logger: 06-09 18:37:41] {2219} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:41] {2392} INFO -  at 79.2s,	estimator lgbm's best error=0.4480,	best estimator lgbm's best error=0.4480
# [flaml.automl.logger: 06-09 18:37:41] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:42] {2392} INFO -  at 79.8s,	estimator lgbm's best error=0.4480,	best estimator lgbm's best error=0.4480
# [flaml.automl.logger: 06-09 18:37:42] {2219} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:42] {2392} INFO -  at 80.3s,	estimator lgbm's best error=0.4480,	best estimator lgbm's best error=0.4480
# [flaml.automl.logger: 06-09 18:37:42] {2219} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:44] {2392} INFO -  at 81.7s,	estimator lgbm's best error=0.3661,	best estimator lgbm's best error=0.3661
# [flaml.automl.logger: 06-09 18:37:44] {2219} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:44] {2392} INFO -  at 82.4s,	estimator lgbm's best error=0.3661,	best estimator lgbm's best error=0.3661
# [flaml.automl.logger: 06-09 18:37:44] {2219} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:46] {2392} INFO -  at 83.7s,	estimator lgbm's best error=0.3586,	best estimator lgbm's best error=0.3586
# [flaml.automl.logger: 06-09 18:37:46] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:47] {2392} INFO -  at 85.5s,	estimator lgbm's best error=0.3557,	best estimator lgbm's best error=0.3557
# [flaml.automl.logger: 06-09 18:37:47] {2219} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:49] {2392} INFO -  at 86.5s,	estimator lgbm's best error=0.3557,	best estimator lgbm's best error=0.3557
# [flaml.automl.logger: 06-09 18:37:49] {2219} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:50] {2392} INFO -  at 88.4s,	estimator lgbm's best error=0.3543,	best estimator lgbm's best error=0.3543
# [flaml.automl.logger: 06-09 18:37:50] {2219} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:52] {2392} INFO -  at 90.1s,	estimator lgbm's best error=0.3543,	best estimator lgbm's best error=0.3543
# [flaml.automl.logger: 06-09 18:37:52] {2219} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:54] {2392} INFO -  at 91.7s,	estimator lgbm's best error=0.3543,	best estimator lgbm's best error=0.3543
# [flaml.automl.logger: 06-09 18:37:54] {2219} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:56] {2392} INFO -  at 93.8s,	estimator lgbm's best error=0.3543,	best estimator lgbm's best error=0.3543
# [flaml.automl.logger: 06-09 18:37:56] {2219} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 06-09 18:37:58] {2392} INFO -  at 96.4s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:37:58] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:01] {2392} INFO -  at 98.9s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:38:01] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:03] {2392} INFO -  at 101.1s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:38:03] {2219} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:05] {2392} INFO -  at 103.3s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:38:05] {2219} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:08] {2392} INFO -  at 106.2s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:38:08] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:10] {2392} INFO -  at 108.2s,	estimator lgbm's best error=0.3532,	best estimator lgbm's best error=0.3532
# [flaml.automl.logger: 06-09 18:38:10] {2219} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:16] {2392} INFO -  at 114.0s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:16] {2219} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:21] {2392} INFO -  at 119.4s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:21] {2219} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:26] {2392} INFO -  at 124.5s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:26] {2219} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:33] {2392} INFO -  at 130.9s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:33] {2219} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:36] {2392} INFO -  at 133.6s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:36] {2219} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 06-09 18:38:42] {2392} INFO -  at 139.9s,	estimator lgbm's best error=0.3349,	best estimator lgbm's best error=0.3349
# [flaml.automl.logger: 06-09 18:38:42] {2219} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 06-09 18:39:04] {2392} INFO -  at 161.7s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 06-09 18:39:04] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 06-09 18:39:22] {2392} INFO -  at 179.7s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 06-09 18:39:22] {2219} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 06-09 18:39:31] {2392} INFO -  at 189.1s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 06-09 18:39:31] {2219} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 06-09 18:39:36] {2392} INFO -  at 194.5s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 06-09 18:39:36] {2219} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 06-09 18:39:55] {2392} INFO -  at 212.6s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 06-09 18:39:55] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 06-09 18:40:12] {2392} INFO -  at 229.9s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:40:12] {2219} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 06-09 18:40:28] {2392} INFO -  at 246.5s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:40:28] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 06-09 18:40:40] {2392} INFO -  at 258.0s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:40:40] {2219} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 06-09 18:40:53] {2392} INFO -  at 270.8s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:40:53] {2219} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 06-09 18:41:01] {2392} INFO -  at 279.3s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:41:01] {2219} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 06-09 18:41:15] {2392} INFO -  at 293.3s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:41:15] {2219} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 06-09 18:41:22] {2392} INFO -  at 300.1s,	estimator lgbm's best error=0.3147,	best estimator lgbm's best error=0.3147
# [flaml.automl.logger: 06-09 18:41:22] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 06-09 18:46:05] {2392} INFO -  at 583.0s,	estimator lgbm's best error=0.2789,	best estimator lgbm's best error=0.2789
# [flaml.automl.logger: 06-09 18:51:39] {2628} INFO - retrain lgbm for 333.6s
# [flaml.automl.logger: 06-09 18:51:39] {2631} INFO - retrained model: LGBMRegressor(colsample_bytree=0.7298650648227573,
#               learning_rate=0.20607567441549396, max_bin=255,
#               min_child_samples=2, n_estimators=1, n_jobs=-1, num_leaves=34,
#               reg_alpha=0.0009765625, reg_lambda=0.9445363699513247,
#               verbose=-1)
# [flaml.automl.logger: 06-09 18:51:39] {1931} INFO - fit succeeded
# [flaml.automl.logger: 06-09 18:51:39] {1932} INFO - Time taken to find the best model: 582.963042974472

# %%
from flaml.automl.data import get_output_from_log
time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history = get_output_from_log(filename=settings['log_file_name'], time_budget=600)
plt.title('Learning Curve')
plt.xlabel('Wall Clock Time (s)')
plt.ylabel('Validation r2')
plt.step(time_history, 1 - np.array(best_valid_loss_history), where='post')
plt.show()

# %%
print("Best hyperparmeter config:", automl.best_config)
print("Best r2 on validation data: {0:.4g}".format(1 - automl.best_loss))
print("Training duration of best run: {0:.4g} s".format(automl.best_config_train_time))
print(automl.model.estimator)
# Out:
# Best hyperparmeter config: {'n_estimators': 188, 'num_leaves': 34, 'min_child_samples': 2, 'learning_rate': 0.20607567441549396, 'log_max_bin': 8, 'colsample_bytree': 0.7298650648227573, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.9445363699513247}
# Best r2 on validation data: 0.7211
# Training duration of best run: 333.6 s
# LGBMRegressor(colsample_bytree=0.7298650648227573,
#               learning_rate=0.20607567441549396, max_bin=255,
#               min_child_samples=2, n_estimators=1, n_jobs=-1, num_leaves=34,
#               reg_alpha=0.0009765625, reg_lambda=0.9445363699513247,
#               verbose=-1)

# %%
# Make predictions on the training and validation data. 
pred_train = automl.predict(lgbm_predictor.pred_data.X_train)
pred_val = automl.predict(lgbm_predictor.pred_data.X_val)

# Calculate and print the Root Mean Squared Error (RMSE) for training and validation predictions. 
print("Training RMSE: ", np.sqrt(mse(lgbm_predictor.pred_data.y_train, pred_train)))
print("Validation RMSE: ", np.sqrt(mse(lgbm_predictor.pred_data.y_val, pred_val)))
# Out:
# Training RMSE:  0.4912160707071531
# Validation RMSE:  0.5235348863054484

# %%
# plt.barh(automl.feature_names_in_, automl.feature_importances_)
plt.barh(lgbm_predictor.pred_data.transformed_feature_names, automl.feature_importances_)
# Out:
# <BarContainer object of 18 artists>
